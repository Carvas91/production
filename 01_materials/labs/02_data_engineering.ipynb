# %%
# %load_ext dotenv
# %dotenv

# %%
import os
os.getenv("TICKERS")
# Out:
# '../../05_src/data/tickers/sp500_wiki.csv'

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2013-12-02 00:00:00+00:00   17.175095   19.686787   20.154642   19.672144
# 2013-12-03 00:00:00+00:00   17.645266   20.225714   20.227858   19.917143
# 2013-12-04 00:00:00+00:00   17.604137   20.178572   20.328215   20.029285
# 2013-12-05 00:00:00+00:00   17.694492   20.282143   20.540714   20.228930
# 2013-12-06 00:00:00+00:00   17.448977   20.000713   20.241072   19.984644
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00+00:00  193.223389  194.169998  196.270004  193.110001
# 2024-01-26 00:00:00+00:00  191.481918  192.419998  194.759995  191.940002
# 2024-01-29 00:00:00+00:00  190.795288  191.729996  192.199997  189.580002
# 2024-01-30 00:00:00+00:00  187.123276  188.039993  191.800003  187.470001
# 2024-01-31 00:00:00+00:00  183.501022  184.399994  187.100006  184.350006
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2013-12-02 00:00:00+00:00   19.928572  472544800
# 2013-12-03 00:00:00+00:00   19.939285  450968000
# 2013-12-04 00:00:00+00:00   20.196428  377809600
# 2013-12-05 00:00:00+00:00   20.451786  447580000
# 2013-12-06 00:00:00+00:00   20.206785  344352400
# ...                               ...        ...
# 2024-01-25 00:00:00+00:00  195.220001   54822100
# 2024-01-26 00:00:00+00:00  194.270004   44594000
# 2024-01-29 00:00:00+00:00  192.009995   47145600
# 2024-01-30 00:00:00+00:00  190.940002   55859400
# 2024-01-31 00:00:00+00:00  187.039993   55467800
#
# [2558 rows x 6 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)
tickers.head()
# Out:
#   ticker     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                   Biotechnology
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota       20883    66740         1902
# 1     Milwaukee, Wisconsin       42942    91142         1916
# 2  North Chicago, Illinois       20883     1800         1888
# 3  North Chicago, Illinois       41274  1551152  2013 (1888)
# 4          Dublin, Ireland       40730  1467373         1989

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]
tech_sector
# Out:
#     ticker                Security             GICS Sector  \
# 4      ACN               Accenture  Information Technology
# 5     ADBE              Adobe Inc.  Information Technology
# 6      AMD  Advanced Micro Devices  Information Technology
# 12    AKAM                  Akamai  Information Technology
# 34     APH                Amphenol  Information Technology
# ..     ...                     ...                     ...
# 450   TRMB            Trimble Inc.  Information Technology
# 452    TYL      Tyler Technologies  Information Technology
# 467   VRSN                Verisign  Information Technology
# 488    WDC         Western Digital  Information Technology
# 499   ZBRA      Zebra Technologies  Information Technology
#
#                               GICS Sub-Industry     Headquarters Location  \
# 4                IT Consulting & Other Services           Dublin, Ireland
# 5                          Application Software      San Jose, California
# 6                                Semiconductors   Santa Clara, California
# 12           Internet Services & Infrastructure  Cambridge, Massachusetts
# 34                        Electronic Components  Wallingford, Connecticut
# ..                                          ...                       ...
# 450          Electronic Equipment & Instruments     Westminster, Colorado
# 452                        Application Software              Plano, Texas
# 467          Internet Services & Infrastructure          Dulles, Virginia
# 488  Technology Hardware, Storage & Peripherals      San Jose, California
# 499          Electronic Equipment & Instruments    Lincolnshire, Illinois
#
#      Date added      CIK Founded
# 4         40730  1467373    1989
# 5         35555   796343    1982
# 6         42814     2488    1969
# 12        39275  1086222    1998
# 34        39721   820313    1932
# ..          ...      ...     ...
# 450       44217   864749    1978
# 452       44004   860731    1966
# 467       38749  1014473    1995
# 488       39995   106040    1970
# 499       43822   877212    1969
#
# [64 rows x 8 columns]

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()
tech_tickers
# Out:
# ['ACN',
#  'ADBE',
#  'AMD',
#  'AKAM',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AAPL',
#  'AMAT',
#  'ANET',
#  'ADSK',
#  'AVGO',
#  'CDNS',
#  'CDW',
#  'CSCO',
#  'CTSH',
#  'GLW',
#  'ENPH',
#  'EPAM',
#  'FFIV',
#  'FICO',
#  'FSLR',
#  'FTNT',
#  'IT',
#  'GEN',
#  'HPE',
#  'HPQ',
#  'IBM',
#  'INTC',
#  'INTU',
#  'JBL',
#  'JNPR',
#  'KEYS',
#  'KLAC',
#  'LRCX',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MPWR',
#  'MSI',
#  'NTAP',
#  'NVDA',
#  'NXPI',
#  'ON',
#  'ORCL',
#  'PANW',
#  'PTC',
#  'QRVO',
#  'QCOM',
#  'ROP',
#  'CRM',
#  'STX',
#  'NOW',
#  'SWKS',
#  'SNPS',
#  'TEL',
#  'TDY',
#  'TER',
#  'TXN',
#  'TRMB',
#  'TYL',
#  'VRSN',
#  'WDC',
#  'ZBRA']

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %%
tech_raw_dt.stack(future_stack=True)
# Out:
# Price                              Adj Close       Close        High  \
# Date                      Ticker
# 2000-01-03 00:00:00+00:00 AAPL      0.843076    0.999442    1.004464
#                           ACN            NaN         NaN         NaN
#                           ADBE     16.274668   16.390625   16.875000
#                           ADI      28.095678   45.093750   46.937500
#                           ADSK      8.052905    8.343750    8.656250
# ...                                      ...         ...         ...
# 2025-01-24 00:00:00+00:00 TXN     185.520004  185.520004  191.500000
#                           TYL     591.929993  591.929993  594.969971
#                           VRSN    210.729996  210.729996  210.880005
#                           WDC      67.410004   67.410004   69.440002
#                           ZBRA    414.609985  414.609985  420.079987
#
# Price                                    Low        Open       Volume
# Date                      Ticker
# 2000-01-03 00:00:00+00:00 AAPL      0.907924    0.936384  535796800.0
#                           ACN            NaN         NaN          NaN
#                           ADBE     16.062500   16.812500    7384400.0
#                           ADI      44.000000   46.750000    3655600.0
#                           ADSK      8.031250    8.500000    2845600.0
# ...                                      ...         ...          ...
# 2025-01-24 00:00:00+00:00 TXN     185.029999  190.000000   15856600.0
#                           TYL     590.210022  591.400024     155300.0
#                           VRSN    206.009995  206.020004     563300.0
#                           WDC      67.360001   68.910004    6046500.0
#                           ZBRA    413.739990  419.059998     258900.0
#
# [403456 rows x 6 columns]

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index().sort_values(['Ticker', 'Date'])
# Out:
# Price                       Date Ticker   Adj Close       Close        High  \
# 0      2000-01-03 00:00:00+00:00   AAPL    0.843076    0.999442    1.004464
# 64     2000-01-04 00:00:00+00:00   AAPL    0.771997    0.915179    0.987723
# 128    2000-01-05 00:00:00+00:00   AAPL    0.783293    0.928571    0.987165
# 192    2000-01-06 00:00:00+00:00   AAPL    0.715509    0.848214    0.955357
# 256    2000-01-07 00:00:00+00:00   AAPL    0.749402    0.888393    0.901786
# ...                          ...    ...         ...         ...         ...
# 403199 2025-01-17 00:00:00+00:00   ZBRA  405.709991  405.709991  407.290009
# 403263 2025-01-21 00:00:00+00:00   ZBRA  418.070007  418.070007  419.850006
# 403327 2025-01-22 00:00:00+00:00   ZBRA  420.570007  420.570007  427.760010
# 403391 2025-01-23 00:00:00+00:00   ZBRA  421.109985  421.109985  422.290009
# 403455 2025-01-24 00:00:00+00:00   ZBRA  414.609985  414.609985  420.079987
#
# Price          Low        Open       Volume
# 0         0.907924    0.936384  535796800.0
# 64        0.903460    0.966518  512377600.0
# 128       0.919643    0.926339  778321600.0
# 192       0.848214    0.947545  767972800.0
# 256       0.852679    0.861607  460734400.0
# ...            ...         ...          ...
# 403199  402.290009  406.040009     270600.0
# 403263  407.619995  407.619995     446000.0
# 403327  419.589996  425.239990     497500.0
# 403391  414.450012  417.619995     377100.0
# 403455  413.739990  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None
tech_dt.columns
# Out:
# Index(['Date', 'Ticker', 'Adj Close', 'Close', 'High', 'Low', 'Open',
#        'Volume'],
#       dtype='object')

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 4.70611310005188 seconds.
# Csv file size 47.817248 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 0.8580923080444336 seconds.
# Parquet file size 16.595028 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\carva\AppData\Local\Temp\ipykernel_22752\3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(ec1a6b2), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000022A6CF0FB80>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:766: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:766: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:766: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\carva\anaconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
#                             Date   Adj Close       Close        High  \
# Ticker
# AAPL   2000-01-03 00:00:00+00:00    0.843076    0.999442    1.004464
# AAPL   2000-01-04 00:00:00+00:00    0.771997    0.915179    0.987723
# AAPL   2000-01-05 00:00:00+00:00    0.783293    0.928571    0.987165
# AAPL   2000-01-06 00:00:00+00:00    0.715509    0.848214    0.955357
# AAPL   2000-01-07 00:00:00+00:00    0.749402    0.888393    0.901786
# ...                          ...         ...         ...         ...
# ZBRA   2025-01-17 00:00:00+00:00  405.709991  405.709991  407.290009
# ZBRA   2025-01-21 00:00:00+00:00  418.070007  418.070007  419.850006
# ZBRA   2025-01-22 00:00:00+00:00  420.570007  420.570007  427.760010
# ZBRA   2025-01-23 00:00:00+00:00  421.109985  421.109985  422.290009
# ZBRA   2025-01-24 00:00:00+00:00  414.609985  414.609985  420.079987
#
#                Low        Open       Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL      0.907924    0.936384  535796800.0  2000          NaN       NaN
# AAPL      0.903460    0.966518  512377600.0  2000     0.999442 -0.084310
# AAPL      0.919643    0.926339  778321600.0  2000     0.915179  0.014633
# AAPL      0.848214    0.947545  767972800.0  2000     0.928571 -0.086538
# AAPL      0.852679    0.861607  460734400.0  2000     0.848214  0.047369
# ...            ...         ...          ...   ...          ...       ...
# ZBRA    402.290009  406.040009     270600.0  2025   402.720001  0.007424
# ZBRA    407.619995  407.619995     446000.0  2025   405.709991  0.030465
# ZBRA    419.589996  425.239990     497500.0  2025   418.070007  0.005980
# ZBRA    414.450012  417.619995     377100.0  2025   420.570007  0.001284
# ZBRA    413.739990  419.059998     258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-01-31 10:37:15,770, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-01-31 10:37:15,770, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-01-31 10:37:15,847, data_manager.py, 57, INFO, Processing all tickers
# 2025-01-31 10:37:15,847, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-01-31 10:37:15,847, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-01-31
# [*********************100%***********************]  503 of 503 completed
#
# 7 Failed downloads:
# ['PXD', 'WRK', 'PEAK', 'FLT', 'MRO', 'BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-01-31)')
# 2025-01-31 10:38:10,529, data_manager.py, 80, INFO, Saving data by year
# 2025-01-31 10:38:10,796, data_manager.py, 83, INFO, Saving data for A
# 2025-01-31 10:38:11,430, data_manager.py, 83, INFO, Saving data for AAL
# 2025-01-31 10:38:12,046, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-01-31 10:38:12,613, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-01-31 10:38:13,271, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-01-31 10:38:14,004, data_manager.py, 83, INFO, Saving data for ABT
# 2025-01-31 10:38:14,654, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-01-31 10:38:15,262, data_manager.py, 83, INFO, Saving data for ACN
# 2025-01-31 10:38:15,921, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-01-31 10:38:16,471, data_manager.py, 83, INFO, Saving data for ADI
# 2025-01-31 10:38:17,021, data_manager.py, 83, INFO, Saving data for ADM
# 2025-01-31 10:38:17,742, data_manager.py, 83, INFO, Saving data for ADP
# 2025-01-31 10:38:18,379, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-01-31 10:38:18,996, data_manager.py, 83, INFO, Saving data for AEE
# 2025-01-31 10:38:19,688, data_manager.py, 83, INFO, Saving data for AEP
# 2025-01-31 10:38:20,429, data_manager.py, 83, INFO, Saving data for AES
# 2025-01-31 10:38:21,063, data_manager.py, 83, INFO, Saving data for AFL
# 2025-01-31 10:38:21,596, data_manager.py, 83, INFO, Saving data for AIG
# 2025-01-31 10:38:22,204, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-01-31 10:38:22,845, data_manager.py, 83, INFO, Saving data for AJG
# 2025-01-31 10:38:23,454, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-01-31 10:38:24,054, data_manager.py, 83, INFO, Saving data for ALB
# 2025-01-31 10:38:24,721, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-01-31 10:38:25,411, data_manager.py, 83, INFO, Saving data for ALL
# 2025-01-31 10:38:26,021, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-01-31 10:38:26,621, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-01-31 10:38:27,396, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-01-31 10:38:28,121, data_manager.py, 83, INFO, Saving data for AMD
# 2025-01-31 10:38:28,679, data_manager.py, 83, INFO, Saving data for AME
# 2025-01-31 10:38:29,287, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-01-31 10:38:30,028, data_manager.py, 83, INFO, Saving data for AMP
# 2025-01-31 10:38:30,778, data_manager.py, 83, INFO, Saving data for AMT
# 2025-01-31 10:38:31,573, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-01-31 10:38:32,330, data_manager.py, 83, INFO, Saving data for ANET
# 2025-01-31 10:38:32,904, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-01-31 10:38:33,629, data_manager.py, 83, INFO, Saving data for AON
# 2025-01-31 10:38:34,294, data_manager.py, 83, INFO, Saving data for AOS
# 2025-01-31 10:38:34,943, data_manager.py, 83, INFO, Saving data for APA
# 2025-01-31 10:38:35,639, data_manager.py, 83, INFO, Saving data for APD
# 2025-01-31 10:38:36,252, data_manager.py, 83, INFO, Saving data for APH
# 2025-01-31 10:38:36,939, data_manager.py, 83, INFO, Saving data for APTV
# 2025-01-31 10:38:37,673, data_manager.py, 83, INFO, Saving data for ARE
# 2025-01-31 10:38:38,358, data_manager.py, 83, INFO, Saving data for ATO
# 2025-01-31 10:38:39,179, data_manager.py, 83, INFO, Saving data for AVB
# 2025-01-31 10:38:39,809, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-01-31 10:38:40,490, data_manager.py, 83, INFO, Saving data for AVY
# 2025-01-31 10:38:41,295, data_manager.py, 83, INFO, Saving data for AWK
# 2025-01-31 10:38:41,977, data_manager.py, 83, INFO, Saving data for AXON
# 2025-01-31 10:38:42,621, data_manager.py, 83, INFO, Saving data for AXP
# 2025-01-31 10:38:43,364, data_manager.py, 83, INFO, Saving data for AZO
# 2025-01-31 10:38:44,000, data_manager.py, 83, INFO, Saving data for BA
# 2025-01-31 10:38:44,637, data_manager.py, 83, INFO, Saving data for BAC
# 2025-01-31 10:38:45,400, data_manager.py, 83, INFO, Saving data for BALL
# 2025-01-31 10:38:46,013, data_manager.py, 83, INFO, Saving data for BAX
# 2025-01-31 10:38:46,772, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-01-31 10:38:47,465, data_manager.py, 83, INFO, Saving data for BBY
# 2025-01-31 10:38:48,232, data_manager.py, 83, INFO, Saving data for BDX
# 2025-01-31 10:38:48,930, data_manager.py, 83, INFO, Saving data for BEN
# 2025-01-31 10:38:49,635, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-01-31 10:38:50,341, data_manager.py, 83, INFO, Saving data for BG
# 2025-01-31 10:38:50,857, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-01-31 10:38:51,553, data_manager.py, 83, INFO, Saving data for BIO
# 2025-01-31 10:38:52,173, data_manager.py, 83, INFO, Saving data for BK
# 2025-01-31 10:38:52,771, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-01-31 10:38:53,454, data_manager.py, 83, INFO, Saving data for BKR
# 2025-01-31 10:38:54,024, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-01-31 10:38:54,726, data_manager.py, 83, INFO, Saving data for BLK
# 2025-01-31 10:38:55,271, data_manager.py, 83, INFO, Saving data for BMY
# 2025-01-31 10:38:55,979, data_manager.py, 83, INFO, Saving data for BR
# 2025-01-31 10:38:56,560, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-01-31 10:38:57,210, data_manager.py, 83, INFO, Saving data for BRO
# 2025-01-31 10:38:57,803, data_manager.py, 83, INFO, Saving data for BSX
# 2025-01-31 10:38:58,404, data_manager.py, 83, INFO, Saving data for BWA
# 2025-01-31 10:38:59,016, data_manager.py, 83, INFO, Saving data for BX
# 2025-01-31 10:38:59,753, data_manager.py, 83, INFO, Saving data for BXP
# 2025-01-31 10:39:00,525, data_manager.py, 83, INFO, Saving data for C
# 2025-01-31 10:39:01,202, data_manager.py, 83, INFO, Saving data for CAG
# 2025-01-31 10:39:01,773, data_manager.py, 83, INFO, Saving data for CAH
# 2025-01-31 10:39:02,381, data_manager.py, 83, INFO, Saving data for CARR
# 2025-01-31 10:39:02,968, data_manager.py, 83, INFO, Saving data for CAT
# 2025-01-31 10:39:03,567, data_manager.py, 83, INFO, Saving data for CB
# 2025-01-31 10:39:04,244, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-01-31 10:39:04,766, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-01-31 10:39:05,371, data_manager.py, 83, INFO, Saving data for CCI
# 2025-01-31 10:39:06,043, data_manager.py, 83, INFO, Saving data for CCL
# 2025-01-31 10:39:06,588, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-01-31 10:39:07,122, data_manager.py, 83, INFO, Saving data for CDW
# 2025-01-31 10:39:07,642, data_manager.py, 83, INFO, Saving data for CE
# 2025-01-31 10:39:08,245, data_manager.py, 83, INFO, Saving data for CEG
# 2025-01-31 10:39:08,936, data_manager.py, 83, INFO, Saving data for CF
# 2025-01-31 10:39:09,530, data_manager.py, 83, INFO, Saving data for CFG
# 2025-01-31 10:39:10,113, data_manager.py, 83, INFO, Saving data for CHD
# 2025-01-31 10:39:10,677, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-01-31 10:39:11,178, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-01-31 10:39:11,751, data_manager.py, 83, INFO, Saving data for CI
# 2025-01-31 10:39:12,439, data_manager.py, 83, INFO, Saving data for CINF
# 2025-01-31 10:39:12,996, data_manager.py, 83, INFO, Saving data for CL
# 2025-01-31 10:39:13,594, data_manager.py, 83, INFO, Saving data for CLX
# 2025-01-31 10:39:14,297, data_manager.py, 83, INFO, Saving data for CMA
# 2025-01-31 10:39:14,964, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-01-31 10:39:15,607, data_manager.py, 83, INFO, Saving data for CME
# 2025-01-31 10:39:16,274, data_manager.py, 83, INFO, Saving data for CMG
# 2025-01-31 10:39:16,913, data_manager.py, 83, INFO, Saving data for CMI
# 2025-01-31 10:39:17,496, data_manager.py, 83, INFO, Saving data for CMS
# 2025-01-31 10:39:18,153, data_manager.py, 83, INFO, Saving data for CNC
# 2025-01-31 10:39:18,946, data_manager.py, 83, INFO, Saving data for CNP
# 2025-01-31 10:39:20,926, data_manager.py, 83, INFO, Saving data for COF
# 2025-01-31 10:39:22,963, data_manager.py, 83, INFO, Saving data for COO
# 2025-01-31 10:39:24,738, data_manager.py, 83, INFO, Saving data for COP
# 2025-01-31 10:39:25,879, data_manager.py, 83, INFO, Saving data for COR
# 2025-01-31 10:39:27,828, data_manager.py, 83, INFO, Saving data for COST
# 2025-01-31 10:39:29,595, data_manager.py, 83, INFO, Saving data for CPB
# 2025-01-31 10:39:31,688, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-01-31 10:39:33,476, data_manager.py, 83, INFO, Saving data for CPT
# 2025-01-31 10:39:35,421, data_manager.py, 83, INFO, Saving data for CRL
# 2025-01-31 10:39:37,364, data_manager.py, 83, INFO, Saving data for CRM
# 2025-01-31 10:39:39,031, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-01-31 10:39:41,468, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-01-31 10:39:43,208, data_manager.py, 83, INFO, Saving data for CSX
# 2025-01-31 10:39:45,078, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-01-31 10:39:47,063, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-01-31 10:39:48,996, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-01-31 10:39:51,174, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-01-31 10:39:53,165, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-01-31 10:39:55,293, data_manager.py, 83, INFO, Saving data for CVS
# 2025-01-31 10:39:57,003, data_manager.py, 83, INFO, Saving data for CVX
# 2025-01-31 10:39:59,268, data_manager.py, 83, INFO, Saving data for CZR
# 2025-01-31 10:40:01,212, data_manager.py, 83, INFO, Saving data for D
# 2025-01-31 10:40:03,188, data_manager.py, 83, INFO, Saving data for DAL
# 2025-01-31 10:40:05,143, data_manager.py, 83, INFO, Saving data for DAY
# 2025-01-31 10:40:07,069, data_manager.py, 83, INFO, Saving data for DD
# 2025-01-31 10:40:08,798, data_manager.py, 83, INFO, Saving data for DE
# 2025-01-31 10:40:10,578, data_manager.py, 83, INFO, Saving data for DFS
# 2025-01-31 10:40:12,631, data_manager.py, 83, INFO, Saving data for DG
# 2025-01-31 10:40:14,598, data_manager.py, 83, INFO, Saving data for DGX
# 2025-01-31 10:40:16,598, data_manager.py, 83, INFO, Saving data for DHI
# 2025-01-31 10:40:18,578, data_manager.py, 83, INFO, Saving data for DHR
# 2025-01-31 10:40:20,369, data_manager.py, 83, INFO, Saving data for DIS
# 2025-01-31 10:40:22,031, data_manager.py, 83, INFO, Saving data for DLR
# 2025-01-31 10:40:23,898, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-01-31 10:40:25,520, data_manager.py, 83, INFO, Saving data for DOV
# 2025-01-31 10:40:27,745, data_manager.py, 83, INFO, Saving data for DOW
# 2025-01-31 10:40:29,668, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-01-31 10:40:32,298, data_manager.py, 83, INFO, Saving data for DRI
# 2025-01-31 10:40:34,519, data_manager.py, 83, INFO, Saving data for DTE
# 2025-01-31 10:40:36,745, data_manager.py, 83, INFO, Saving data for DUK
# 2025-01-31 10:40:38,066, data_manager.py, 83, INFO, Saving data for DVA
# 2025-01-31 10:40:39,172, data_manager.py, 83, INFO, Saving data for DVN
# 2025-01-31 10:40:40,836, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-01-31 10:40:42,808, data_manager.py, 83, INFO, Saving data for EA
# 2025-01-31 10:40:44,718, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-01-31 10:40:46,615, data_manager.py, 83, INFO, Saving data for ECL
# 2025-01-31 10:40:48,563, data_manager.py, 83, INFO, Saving data for ED
# 2025-01-31 10:40:50,483, data_manager.py, 83, INFO, Saving data for EFX
# 2025-01-31 10:40:52,348, data_manager.py, 83, INFO, Saving data for EG
# 2025-01-31 10:40:54,225, data_manager.py, 83, INFO, Saving data for EIX
# 2025-01-31 10:40:56,038, data_manager.py, 83, INFO, Saving data for EL
# 2025-01-31 10:40:57,935, data_manager.py, 83, INFO, Saving data for ELV
# 2025-01-31 10:40:59,965, data_manager.py, 83, INFO, Saving data for EMN
# 2025-01-31 10:41:02,070, data_manager.py, 83, INFO, Saving data for EMR
# 2025-01-31 10:41:03,918, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-01-31 10:41:05,938, data_manager.py, 83, INFO, Saving data for EOG
# 2025-01-31 10:41:07,810, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-01-31 10:41:10,058, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-01-31 10:41:12,111, data_manager.py, 83, INFO, Saving data for EQR
# 2025-01-31 10:41:13,938, data_manager.py, 83, INFO, Saving data for EQT
# 2025-01-31 10:41:16,125, data_manager.py, 83, INFO, Saving data for ES
# 2025-01-31 10:41:18,159, data_manager.py, 83, INFO, Saving data for ESS
# 2025-01-31 10:41:20,649, data_manager.py, 83, INFO, Saving data for ETN
# 2025-01-31 10:41:22,658, data_manager.py, 83, INFO, Saving data for ETR
# 2025-01-31 10:41:23,358, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-01-31 10:41:24,108, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-01-31 10:41:24,766, data_manager.py, 83, INFO, Saving data for EW
# 2025-01-31 10:41:25,550, data_manager.py, 83, INFO, Saving data for EXC
# 2025-01-31 10:41:26,225, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-01-31 10:41:26,966, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-01-31 10:41:27,524, data_manager.py, 83, INFO, Saving data for EXR
# 2025-01-31 10:41:28,174, data_manager.py, 83, INFO, Saving data for F
# 2025-01-31 10:41:28,866, data_manager.py, 83, INFO, Saving data for FANG
# 2025-01-31 10:41:29,524, data_manager.py, 83, INFO, Saving data for FAST
# 2025-01-31 10:41:30,181, data_manager.py, 83, INFO, Saving data for FCX
# 2025-01-31 10:41:30,949, data_manager.py, 83, INFO, Saving data for FDS
# 2025-01-31 10:41:31,669, data_manager.py, 83, INFO, Saving data for FDX
# 2025-01-31 10:41:32,416, data_manager.py, 83, INFO, Saving data for FE
# 2025-01-31 10:41:33,091, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-01-31 10:41:33,816, data_manager.py, 83, INFO, Saving data for FI
# 2025-01-31 10:41:34,623, data_manager.py, 83, INFO, Saving data for FICO
# 2025-01-31 10:41:35,391, data_manager.py, 83, INFO, Saving data for FIS
# 2025-01-31 10:41:35,987, data_manager.py, 83, INFO, Saving data for FITB
# 2025-01-31 10:41:36,648, data_manager.py, 83, INFO, Saving data for FLT
# 2025-01-31 10:41:37,248, data_manager.py, 83, INFO, Saving data for FMC
# 2025-01-31 10:41:37,948, data_manager.py, 83, INFO, Saving data for FOX
# 2025-01-31 10:41:38,643, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-01-31 10:41:39,312, data_manager.py, 83, INFO, Saving data for FRT
# 2025-01-31 10:41:39,957, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-01-31 10:41:40,602, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-01-31 10:41:41,263, data_manager.py, 83, INFO, Saving data for FTV
# 2025-01-31 10:41:42,022, data_manager.py, 83, INFO, Saving data for GD
# 2025-01-31 10:41:42,770, data_manager.py, 83, INFO, Saving data for GE
# 2025-01-31 10:41:43,441, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-01-31 10:41:44,073, data_manager.py, 83, INFO, Saving data for GEN
# 2025-01-31 10:41:44,652, data_manager.py, 83, INFO, Saving data for GILD
# 2025-01-31 10:41:45,331, data_manager.py, 83, INFO, Saving data for GIS
# 2025-01-31 10:41:45,998, data_manager.py, 83, INFO, Saving data for GL
# 2025-01-31 10:41:46,507, data_manager.py, 83, INFO, Saving data for GLW
# 2025-01-31 10:41:47,090, data_manager.py, 83, INFO, Saving data for GM
# 2025-01-31 10:41:47,698, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-01-31 10:41:48,298, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-01-31 10:41:48,889, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-01-31 10:41:49,481, data_manager.py, 83, INFO, Saving data for GPC
# 2025-01-31 10:41:50,099, data_manager.py, 83, INFO, Saving data for GPN
# 2025-01-31 10:41:50,649, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-01-31 10:41:51,272, data_manager.py, 83, INFO, Saving data for GS
# 2025-01-31 10:41:51,849, data_manager.py, 83, INFO, Saving data for GWW
# 2025-01-31 10:41:52,440, data_manager.py, 83, INFO, Saving data for HAL
# 2025-01-31 10:41:53,022, data_manager.py, 83, INFO, Saving data for HAS
# 2025-01-31 10:41:53,657, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-01-31 10:41:54,323, data_manager.py, 83, INFO, Saving data for HCA
# 2025-01-31 10:41:54,989, data_manager.py, 83, INFO, Saving data for HD
# 2025-01-31 10:41:55,731, data_manager.py, 83, INFO, Saving data for HES
# 2025-01-31 10:41:56,299, data_manager.py, 83, INFO, Saving data for HIG
# 2025-01-31 10:41:56,940, data_manager.py, 83, INFO, Saving data for HII
# 2025-01-31 10:41:57,598, data_manager.py, 83, INFO, Saving data for HLT
# 2025-01-31 10:41:58,182, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-01-31 10:41:58,840, data_manager.py, 83, INFO, Saving data for HON
# 2025-01-31 10:41:59,457, data_manager.py, 83, INFO, Saving data for HPE
# 2025-01-31 10:42:00,191, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-01-31 10:42:00,839, data_manager.py, 83, INFO, Saving data for HRL
# 2025-01-31 10:42:01,473, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-01-31 10:42:02,183, data_manager.py, 83, INFO, Saving data for HST
# 2025-01-31 10:42:02,831, data_manager.py, 83, INFO, Saving data for HSY
# 2025-01-31 10:42:03,557, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-01-31 10:42:04,240, data_manager.py, 83, INFO, Saving data for HUM
# 2025-01-31 10:42:04,853, data_manager.py, 83, INFO, Saving data for HWM
# 2025-01-31 10:42:05,462, data_manager.py, 83, INFO, Saving data for IBM
# 2025-01-31 10:42:06,022, data_manager.py, 83, INFO, Saving data for ICE
# 2025-01-31 10:42:06,754, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-01-31 10:42:07,403, data_manager.py, 83, INFO, Saving data for IEX
# 2025-01-31 10:42:08,093, data_manager.py, 83, INFO, Saving data for IFF
# 2025-01-31 10:42:08,738, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-01-31 10:42:09,332, data_manager.py, 83, INFO, Saving data for INCY
# 2025-01-31 10:42:09,936, data_manager.py, 83, INFO, Saving data for INTC
# 2025-01-31 10:42:10,578, data_manager.py, 83, INFO, Saving data for INTU
# 2025-01-31 10:42:11,215, data_manager.py, 83, INFO, Saving data for INVH
# 2025-01-31 10:42:11,850, data_manager.py, 83, INFO, Saving data for IP
# 2025-01-31 10:42:12,452, data_manager.py, 83, INFO, Saving data for IPG
# 2025-01-31 10:42:13,014, data_manager.py, 83, INFO, Saving data for IQV
# 2025-01-31 10:42:13,610, data_manager.py, 83, INFO, Saving data for IR
# 2025-01-31 10:42:14,139, data_manager.py, 83, INFO, Saving data for IRM
# 2025-01-31 10:42:14,738, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-01-31 10:42:15,313, data_manager.py, 83, INFO, Saving data for IT
# 2025-01-31 10:42:15,956, data_manager.py, 83, INFO, Saving data for ITW
# 2025-01-31 10:42:16,477, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-01-31 10:42:17,037, data_manager.py, 83, INFO, Saving data for J
# 2025-01-31 10:42:17,666, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-01-31 10:42:18,211, data_manager.py, 83, INFO, Saving data for JBL
# 2025-01-31 10:42:18,728, data_manager.py, 83, INFO, Saving data for JCI
# 2025-01-31 10:42:19,217, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-01-31 10:42:19,862, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-01-31 10:42:20,430, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-01-31 10:42:21,009, data_manager.py, 83, INFO, Saving data for JPM
# 2025-01-31 10:42:21,750, data_manager.py, 83, INFO, Saving data for K
# 2025-01-31 10:42:22,315, data_manager.py, 83, INFO, Saving data for KDP
# 2025-01-31 10:42:22,899, data_manager.py, 83, INFO, Saving data for KEY
# 2025-01-31 10:42:23,510, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-01-31 10:42:24,035, data_manager.py, 83, INFO, Saving data for KHC
# 2025-01-31 10:42:24,830, data_manager.py, 83, INFO, Saving data for KIM
# 2025-01-31 10:42:25,540, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-01-31 10:42:26,131, data_manager.py, 83, INFO, Saving data for KMB
# 2025-01-31 10:42:26,817, data_manager.py, 83, INFO, Saving data for KMI
# 2025-01-31 10:42:27,323, data_manager.py, 83, INFO, Saving data for KMX
# 2025-01-31 10:42:27,923, data_manager.py, 83, INFO, Saving data for KO
# 2025-01-31 10:42:28,497, data_manager.py, 83, INFO, Saving data for KR
# 2025-01-31 10:42:29,192, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-01-31 10:42:29,853, data_manager.py, 83, INFO, Saving data for L
# 2025-01-31 10:42:30,410, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-01-31 10:42:30,993, data_manager.py, 83, INFO, Saving data for LEN
# 2025-01-31 10:42:31,513, data_manager.py, 83, INFO, Saving data for LH
# 2025-01-31 10:42:32,075, data_manager.py, 83, INFO, Saving data for LHX
# 2025-01-31 10:42:32,634, data_manager.py, 83, INFO, Saving data for LIN
# 2025-01-31 10:42:33,236, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-01-31 10:42:33,764, data_manager.py, 83, INFO, Saving data for LLY
# 2025-01-31 10:42:34,340, data_manager.py, 83, INFO, Saving data for LMT
# 2025-01-31 10:42:34,934, data_manager.py, 83, INFO, Saving data for LNT
# 2025-01-31 10:42:35,493, data_manager.py, 83, INFO, Saving data for LOW
# 2025-01-31 10:42:36,035, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-01-31 10:42:36,658, data_manager.py, 83, INFO, Saving data for LULU
# 2025-01-31 10:42:37,302, data_manager.py, 83, INFO, Saving data for LUV
# 2025-01-31 10:42:37,933, data_manager.py, 83, INFO, Saving data for LVS
# 2025-01-31 10:42:38,422, data_manager.py, 83, INFO, Saving data for LW
# 2025-01-31 10:42:38,988, data_manager.py, 83, INFO, Saving data for LYB
# 2025-01-31 10:42:39,580, data_manager.py, 83, INFO, Saving data for LYV
# 2025-01-31 10:42:40,122, data_manager.py, 83, INFO, Saving data for MA
# 2025-01-31 10:42:40,631, data_manager.py, 83, INFO, Saving data for MAA
# 2025-01-31 10:42:41,207, data_manager.py, 83, INFO, Saving data for MAR
# 2025-01-31 10:42:41,821, data_manager.py, 83, INFO, Saving data for MAS
# 2025-01-31 10:42:42,410, data_manager.py, 83, INFO, Saving data for MCD
# 2025-01-31 10:42:43,115, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-01-31 10:42:43,815, data_manager.py, 83, INFO, Saving data for MCK
# 2025-01-31 10:42:44,458, data_manager.py, 83, INFO, Saving data for MCO
# 2025-01-31 10:42:45,057, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-01-31 10:42:45,659, data_manager.py, 83, INFO, Saving data for MDT
# 2025-01-31 10:42:46,356, data_manager.py, 83, INFO, Saving data for MET
# 2025-01-31 10:42:47,042, data_manager.py, 83, INFO, Saving data for META
# 2025-01-31 10:42:47,708, data_manager.py, 83, INFO, Saving data for MGM
# 2025-01-31 10:42:48,390, data_manager.py, 83, INFO, Saving data for MHK
# 2025-01-31 10:42:48,969, data_manager.py, 83, INFO, Saving data for MKC
# 2025-01-31 10:42:49,563, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-01-31 10:42:50,202, data_manager.py, 83, INFO, Saving data for MLM
# 2025-01-31 10:42:50,826, data_manager.py, 83, INFO, Saving data for MMC
# 2025-01-31 10:42:51,485, data_manager.py, 83, INFO, Saving data for MMM
# 2025-01-31 10:42:52,039, data_manager.py, 83, INFO, Saving data for MNST
# 2025-01-31 10:42:52,702, data_manager.py, 83, INFO, Saving data for MO
# 2025-01-31 10:42:53,246, data_manager.py, 83, INFO, Saving data for MOH
# 2025-01-31 10:42:53,775, data_manager.py, 83, INFO, Saving data for MOS
# 2025-01-31 10:42:54,399, data_manager.py, 83, INFO, Saving data for MPC
# 2025-01-31 10:42:55,131, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-01-31 10:42:55,762, data_manager.py, 83, INFO, Saving data for MRK
# 2025-01-31 10:42:56,344, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-01-31 10:42:57,047, data_manager.py, 83, INFO, Saving data for MRO
# 2025-01-31 10:42:57,701, data_manager.py, 83, INFO, Saving data for MS
# 2025-01-31 10:42:58,427, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-01-31 10:42:59,067, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-01-31 10:42:59,705, data_manager.py, 83, INFO, Saving data for MSI
# 2025-01-31 10:43:00,395, data_manager.py, 83, INFO, Saving data for MTB
# 2025-01-31 10:43:01,147, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-01-31 10:43:01,844, data_manager.py, 83, INFO, Saving data for MTD
# 2025-01-31 10:43:02,458, data_manager.py, 83, INFO, Saving data for MU
# 2025-01-31 10:43:03,011, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-01-31 10:43:03,682, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-01-31 10:43:04,339, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-01-31 10:43:04,947, data_manager.py, 83, INFO, Saving data for NEE
# 2025-01-31 10:43:05,670, data_manager.py, 83, INFO, Saving data for NEM
# 2025-01-31 10:43:06,322, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-01-31 10:43:07,046, data_manager.py, 83, INFO, Saving data for NI
# 2025-01-31 10:43:07,748, data_manager.py, 83, INFO, Saving data for NKE
# 2025-01-31 10:43:08,373, data_manager.py, 83, INFO, Saving data for NOC
# 2025-01-31 10:43:09,023, data_manager.py, 83, INFO, Saving data for NOW
# 2025-01-31 10:43:09,699, data_manager.py, 83, INFO, Saving data for NRG
# 2025-01-31 10:43:10,452, data_manager.py, 83, INFO, Saving data for NSC
# 2025-01-31 10:43:11,080, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-01-31 10:43:11,736, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-01-31 10:43:12,423, data_manager.py, 83, INFO, Saving data for NUE
# 2025-01-31 10:43:13,163, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-01-31 10:43:13,797, data_manager.py, 83, INFO, Saving data for NVR
# 2025-01-31 10:43:14,383, data_manager.py, 83, INFO, Saving data for NWS
# 2025-01-31 10:43:15,391, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-01-31 10:43:16,772, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-01-31 10:43:19,049, data_manager.py, 83, INFO, Saving data for O
# 2025-01-31 10:43:20,982, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-01-31 10:43:22,181, data_manager.py, 83, INFO, Saving data for OKE
# 2025-01-31 10:43:24,212, data_manager.py, 83, INFO, Saving data for OMC
# 2025-01-31 10:43:26,529, data_manager.py, 83, INFO, Saving data for ON
# 2025-01-31 10:43:28,539, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-01-31 10:43:30,026, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-01-31 10:43:31,407, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-01-31 10:43:33,156, data_manager.py, 83, INFO, Saving data for OXY
# 2025-01-31 10:43:35,030, data_manager.py, 83, INFO, Saving data for PANW
# 2025-01-31 10:43:37,140, data_manager.py, 83, INFO, Saving data for PARA
# 2025-01-31 10:43:38,973, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-01-31 10:43:40,646, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-01-31 10:43:42,337, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-01-31 10:43:44,080, data_manager.py, 83, INFO, Saving data for PCG
# 2025-01-31 10:43:45,859, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-01-31 10:43:47,538, data_manager.py, 83, INFO, Saving data for PEG
# 2025-01-31 10:43:49,352, data_manager.py, 83, INFO, Saving data for PEP
# 2025-01-31 10:43:51,146, data_manager.py, 83, INFO, Saving data for PFE
# 2025-01-31 10:43:52,803, data_manager.py, 83, INFO, Saving data for PFG
# 2025-01-31 10:43:54,402, data_manager.py, 83, INFO, Saving data for PG
# 2025-01-31 10:43:56,058, data_manager.py, 83, INFO, Saving data for PGR
# 2025-01-31 10:43:58,072, data_manager.py, 83, INFO, Saving data for PH
# 2025-01-31 10:43:59,832, data_manager.py, 83, INFO, Saving data for PHM
# 2025-01-31 10:44:01,772, data_manager.py, 83, INFO, Saving data for PKG
# 2025-01-31 10:44:03,640, data_manager.py, 83, INFO, Saving data for PLD
# 2025-01-31 10:44:05,680, data_manager.py, 83, INFO, Saving data for PM
# 2025-01-31 10:44:07,538, data_manager.py, 83, INFO, Saving data for PNC
# 2025-01-31 10:44:09,568, data_manager.py, 83, INFO, Saving data for PNR
# 2025-01-31 10:44:11,614, data_manager.py, 83, INFO, Saving data for PNW
# 2025-01-31 10:44:13,469, data_manager.py, 83, INFO, Saving data for PODD
# 2025-01-31 10:44:15,606, data_manager.py, 83, INFO, Saving data for POOL
# 2025-01-31 10:44:17,381, data_manager.py, 83, INFO, Saving data for PPG
# 2025-01-31 10:44:19,298, data_manager.py, 83, INFO, Saving data for PPL
# 2025-01-31 10:44:20,880, data_manager.py, 83, INFO, Saving data for PRU
# 2025-01-31 10:44:22,743, data_manager.py, 83, INFO, Saving data for PSA
# 2025-01-31 10:44:24,750, data_manager.py, 83, INFO, Saving data for PSX
# 2025-01-31 10:44:26,533, data_manager.py, 83, INFO, Saving data for PTC
# 2025-01-31 10:44:28,868, data_manager.py, 83, INFO, Saving data for PWR
# 2025-01-31 10:44:30,879, data_manager.py, 83, INFO, Saving data for PXD
# 2025-01-31 10:44:32,663, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-01-31 10:44:34,522, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-01-31 10:44:36,644, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-01-31 10:44:38,629, data_manager.py, 83, INFO, Saving data for RCL
# 2025-01-31 10:44:40,435, data_manager.py, 83, INFO, Saving data for REG
# 2025-01-31 10:44:42,447, data_manager.py, 83, INFO, Saving data for REGN
# 2025-01-31 10:44:44,265, data_manager.py, 83, INFO, Saving data for RF
# 2025-01-31 10:44:46,195, data_manager.py, 83, INFO, Saving data for RHI
# 2025-01-31 10:44:48,143, data_manager.py, 83, INFO, Saving data for RJF
# 2025-01-31 10:44:50,056, data_manager.py, 83, INFO, Saving data for RL
# 2025-01-31 10:44:51,969, data_manager.py, 83, INFO, Saving data for RMD
# 2025-01-31 10:44:53,678, data_manager.py, 83, INFO, Saving data for ROK
# 2025-01-31 10:44:55,499, data_manager.py, 83, INFO, Saving data for ROL
# 2025-01-31 10:44:57,272, data_manager.py, 83, INFO, Saving data for ROP
# 2025-01-31 10:44:59,371, data_manager.py, 83, INFO, Saving data for ROST
# 2025-01-31 10:45:01,139, data_manager.py, 83, INFO, Saving data for RSG
# 2025-01-31 10:45:02,905, data_manager.py, 83, INFO, Saving data for RTX
# 2025-01-31 10:45:04,939, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-01-31 10:45:06,538, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-01-31 10:45:08,358, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-01-31 10:45:10,171, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-01-31 10:45:12,179, data_manager.py, 83, INFO, Saving data for SHW
# 2025-01-31 10:45:14,049, data_manager.py, 83, INFO, Saving data for SJM
# 2025-01-31 10:45:15,679, data_manager.py, 83, INFO, Saving data for SLB
# 2025-01-31 10:45:17,572, data_manager.py, 83, INFO, Saving data for SNA
# 2025-01-31 10:45:19,179, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-01-31 10:45:21,104, data_manager.py, 83, INFO, Saving data for SO
# 2025-01-31 10:45:22,908, data_manager.py, 83, INFO, Saving data for SPG
# 2025-01-31 10:45:24,650, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-01-31 10:45:26,406, data_manager.py, 83, INFO, Saving data for SRE
# 2025-01-31 10:45:28,148, data_manager.py, 83, INFO, Saving data for STE
# 2025-01-31 10:45:30,033, data_manager.py, 83, INFO, Saving data for STLD
# 2025-01-31 10:45:32,063, data_manager.py, 83, INFO, Saving data for STT
# 2025-01-31 10:45:33,788, data_manager.py, 83, INFO, Saving data for STX
# 2025-01-31 10:45:35,839, data_manager.py, 83, INFO, Saving data for STZ
# 2025-01-31 10:45:37,454, data_manager.py, 83, INFO, Saving data for SWK
# 2025-01-31 10:45:39,363, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-01-31 10:45:41,344, data_manager.py, 83, INFO, Saving data for SYF
# 2025-01-31 10:45:43,132, data_manager.py, 83, INFO, Saving data for SYK
# 2025-01-31 10:45:45,008, data_manager.py, 83, INFO, Saving data for SYY
# 2025-01-31 10:45:46,893, data_manager.py, 83, INFO, Saving data for T
# 2025-01-31 10:45:48,697, data_manager.py, 83, INFO, Saving data for TAP
# 2025-01-31 10:45:50,037, data_manager.py, 83, INFO, Saving data for TDG
# 2025-01-31 10:45:51,121, data_manager.py, 83, INFO, Saving data for TDY
# 2025-01-31 10:45:52,973, data_manager.py, 83, INFO, Saving data for TECH
# 2025-01-31 10:45:54,806, data_manager.py, 83, INFO, Saving data for TEL
# 2025-01-31 10:45:57,018, data_manager.py, 83, INFO, Saving data for TER
# 2025-01-31 10:45:59,716, data_manager.py, 83, INFO, Saving data for TFC
# 2025-01-31 10:46:01,885, data_manager.py, 83, INFO, Saving data for TFX
# 2025-01-31 10:46:04,021, data_manager.py, 83, INFO, Saving data for TGT
# 2025-01-31 10:46:06,275, data_manager.py, 83, INFO, Saving data for TJX
# 2025-01-31 10:46:08,317, data_manager.py, 83, INFO, Saving data for TMO
# 2025-01-31 10:46:10,345, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-01-31 10:46:12,308, data_manager.py, 83, INFO, Saving data for TPR
# 2025-01-31 10:46:14,345, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-01-31 10:46:16,204, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-01-31 10:46:18,416, data_manager.py, 83, INFO, Saving data for TROW
# 2025-01-31 10:46:20,367, data_manager.py, 83, INFO, Saving data for TRV
# 2025-01-31 10:46:22,484, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-01-31 10:46:24,545, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-01-31 10:46:26,576, data_manager.py, 83, INFO, Saving data for TSN
# 2025-01-31 10:46:28,526, data_manager.py, 83, INFO, Saving data for TT
# 2025-01-31 10:46:30,360, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-01-31 10:46:32,364, data_manager.py, 83, INFO, Saving data for TXN
# 2025-01-31 10:46:34,528, data_manager.py, 83, INFO, Saving data for TXT
# 2025-01-31 10:46:36,635, data_manager.py, 83, INFO, Saving data for TYL
# 2025-01-31 10:46:38,986, data_manager.py, 83, INFO, Saving data for UAL
# 2025-01-31 10:46:41,005, data_manager.py, 83, INFO, Saving data for UBER
# 2025-01-31 10:46:42,844, data_manager.py, 83, INFO, Saving data for UDR
# 2025-01-31 10:46:44,817, data_manager.py, 83, INFO, Saving data for UHS
# 2025-01-31 10:46:46,900, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-01-31 10:46:48,904, data_manager.py, 83, INFO, Saving data for UNH
# 2025-01-31 10:46:51,017, data_manager.py, 83, INFO, Saving data for UNP
# 2025-01-31 10:46:52,855, data_manager.py, 83, INFO, Saving data for UPS
# 2025-01-31 10:46:54,884, data_manager.py, 83, INFO, Saving data for URI
# 2025-01-31 10:46:56,866, data_manager.py, 83, INFO, Saving data for USB
# 2025-01-31 10:46:58,906, data_manager.py, 83, INFO, Saving data for V
# 2025-01-31 10:47:00,937, data_manager.py, 83, INFO, Saving data for VFC
# 2025-01-31 10:47:03,000, data_manager.py, 83, INFO, Saving data for VICI
# 2025-01-31 10:47:05,116, data_manager.py, 83, INFO, Saving data for VLO
# 2025-01-31 10:47:07,183, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-01-31 10:47:09,325, data_manager.py, 83, INFO, Saving data for VMC
# 2025-01-31 10:47:11,435, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-01-31 10:47:13,359, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-01-31 10:47:15,600, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-01-31 10:47:17,642, data_manager.py, 83, INFO, Saving data for VTR
# 2025-01-31 10:47:19,675, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-01-31 10:47:21,645, data_manager.py, 83, INFO, Saving data for VZ
# 2025-01-31 10:47:23,616, data_manager.py, 83, INFO, Saving data for WAB
# 2025-01-31 10:47:25,875, data_manager.py, 83, INFO, Saving data for WAT
# 2025-01-31 10:47:28,133, data_manager.py, 83, INFO, Saving data for WBA
# 2025-01-31 10:47:30,191, data_manager.py, 83, INFO, Saving data for WBD
# 2025-01-31 10:47:32,414, data_manager.py, 83, INFO, Saving data for WDC
# 2025-01-31 10:47:34,750, data_manager.py, 83, INFO, Saving data for WEC
# 2025-01-31 10:47:37,211, data_manager.py, 83, INFO, Saving data for WELL
# 2025-01-31 10:47:37,971, data_manager.py, 83, INFO, Saving data for WFC
# 2025-01-31 10:47:38,746, data_manager.py, 83, INFO, Saving data for WHR
# 2025-01-31 10:47:39,545, data_manager.py, 83, INFO, Saving data for WM
# 2025-01-31 10:47:40,171, data_manager.py, 83, INFO, Saving data for WMB
# 2025-01-31 10:47:41,280, data_manager.py, 83, INFO, Saving data for WMT
# 2025-01-31 10:47:42,181, data_manager.py, 83, INFO, Saving data for WRB
# 2025-01-31 10:47:42,971, data_manager.py, 83, INFO, Saving data for WRK
# 2025-01-31 10:47:43,761, data_manager.py, 83, INFO, Saving data for WST
# 2025-01-31 10:47:44,530, data_manager.py, 83, INFO, Saving data for WTW
# 2025-01-31 10:47:45,198, data_manager.py, 83, INFO, Saving data for WY
# 2025-01-31 10:47:45,910, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-01-31 10:47:46,565, data_manager.py, 83, INFO, Saving data for XEL
# 2025-01-31 10:47:47,309, data_manager.py, 83, INFO, Saving data for XOM
# 2025-01-31 10:47:48,037, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-01-31 10:47:48,701, data_manager.py, 83, INFO, Saving data for XYL
# 2025-01-31 10:47:49,511, data_manager.py, 83, INFO, Saving data for YUM
# 2025-01-31 10:47:50,287, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-01-31 10:47:51,020, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-01-31 10:47:51,812, data_manager.py, 83, INFO, Saving data for ZION
# 2025-01-31 10:47:52,595, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
